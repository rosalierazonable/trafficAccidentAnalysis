# %% [markdown]
# # Data Cleaning & Restructuring

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %%
# To Display all columns 
pd.set_option('display.max_columns', None)

style.use(['science', 'notebook', 'grid'])

# %%
dallas_city = pd.read_csv('../dataset/raw/Dallas_City_Data_2021.csv', index_col='ID')
dallas_city.head(5)
# Out:
#          Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-11786         2  2016-11-30 15:29:48  2016-11-30 21:29:48   32.84365
# A-11787         2  2016-11-30 15:41:16  2016-11-30 21:41:16   32.84662
# A-11794         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.79385
# A-11795         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.85710
# A-11798         3  2016-11-30 16:21:05  2016-11-30 22:21:05   32.87684
#
#          Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# ID
# A-11786  -96.77463  32.81833 -96.78806         1.915
# A-11787  -96.63736  32.84640 -96.63711         0.021
# A-11794  -96.70278  32.79498 -96.69424         0.502
# A-11795  -96.77046  32.84623 -96.77330         0.769
# A-11798  -96.81001  32.88004 -96.80963         0.222
#
#                                                Description  Number  \
# ID
# A-11786  Between Mockingbird Ln/Exit 3 and Knox St/Hend...     NaN
# A-11787                  At La Prada Dr/Exit 9 - Accident.     NaN
# A-11794               At Jim Miller Rd/Exit 51 - Accident.     NaN
# A-11795  Between Caruth Haven Ln/Exit 4 and Lovers Ln/E...     NaN
# A-11798                      At Walnut Hill Ln - Accident.     NaN
#
#                          Street Side    City  County State Zipcode Country  \
# ID
# A-11786                 US-75 S    R  Dallas  Dallas    TX   75205      US
# A-11787                 I-635 S    R  Dallas  Dallas    TX   75228      US
# A-11794      R L Thornton Fwy E    R  Dallas  Dallas    TX   75228      US
# A-11795       Southwestern Blvd    R  Dallas  Dallas    TX   75225      US
# A-11798  Dallas North Tollway N    R  Dallas  Dallas    TX   75225      US
#
#            Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# ID
# A-11786  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11787  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11794  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11795  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11798  US/Central         KDAL  2016-11-30 15:53:00            61.0
#
#          Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# ID
# A-11786            NaN         22.0         30.01            10.0
# A-11787            NaN         22.0         30.01            10.0
# A-11794            NaN         22.0         30.01            10.0
# A-11795            NaN         22.0         30.01            10.0
# A-11798            NaN         22.0         30.01            10.0
#
#         Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# ID
# A-11786            NNW              4.6                NaN             Clear
# A-11787            NNW              4.6                NaN             Clear
# A-11794            NNW              4.6                NaN             Clear
# A-11795            NNW              4.6                NaN             Clear
# A-11798            NNW              4.6                NaN             Clear
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# ID
# A-11786    False  False     False     False      True    False    False
# A-11787    False  False     False     False     False    False    False
# A-11794    False  False     False     False      True    False    False
# A-11795    False  False      True     False     False    False    False
# A-11798    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# ID
# A-11786       False    False  False            False           False
# A-11787       False    False  False            False           False
# A-11794       False    False  False            False           False
# A-11795       False    False  False            False            True
# A-11798       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# ID
# A-11786         False            Day            Day               Day
# A-11787         False            Day            Day               Day
# A-11794         False            Day            Day               Day
# A-11795         False            Day            Day               Day
# A-11798         False            Day            Day               Day
#
#         Astronomical_Twilight
# ID
# A-11786                   Day
# A-11787                   Day
# A-11794                   Day
# A-11795                   Day
# A-11798                   Day

# %%
# Closer look at the names of the columns or attributes
dallas_city.columns
# Out:
# Index(['Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
dallas_city.shape
# Out:
# (41615, 46)

# %% [markdown]
# ### Make Column names more self-explanatory

# %%
dallas_city.rename(columns={'Number': 'Street_Number', 
                            'Street':'Street_Name', 
                            'Side': 'Street_Side'}, inplace=True)
dallas_city.head()
# Out:
#          Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-11786         2  2016-11-30 15:29:48  2016-11-30 21:29:48   32.84365
# A-11787         2  2016-11-30 15:41:16  2016-11-30 21:41:16   32.84662
# A-11794         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.79385
# A-11795         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.85710
# A-11798         3  2016-11-30 16:21:05  2016-11-30 22:21:05   32.87684
#
#          Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# ID
# A-11786  -96.77463  32.81833 -96.78806         1.915
# A-11787  -96.63736  32.84640 -96.63711         0.021
# A-11794  -96.70278  32.79498 -96.69424         0.502
# A-11795  -96.77046  32.84623 -96.77330         0.769
# A-11798  -96.81001  32.88004 -96.80963         0.222
#
#                                                Description  Street_Number  \
# ID
# A-11786  Between Mockingbird Ln/Exit 3 and Knox St/Hend...            NaN
# A-11787                  At La Prada Dr/Exit 9 - Accident.            NaN
# A-11794               At Jim Miller Rd/Exit 51 - Accident.            NaN
# A-11795  Between Caruth Haven Ln/Exit 4 and Lovers Ln/E...            NaN
# A-11798                      At Walnut Hill Ln - Accident.            NaN
#
#                     Street_Name Street_Side    City  County State Zipcode  \
# ID
# A-11786                 US-75 S           R  Dallas  Dallas    TX   75205
# A-11787                 I-635 S           R  Dallas  Dallas    TX   75228
# A-11794      R L Thornton Fwy E           R  Dallas  Dallas    TX   75228
# A-11795       Southwestern Blvd           R  Dallas  Dallas    TX   75225
# A-11798  Dallas North Tollway N           R  Dallas  Dallas    TX   75225
#
#         Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# ID
# A-11786      US  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11787      US  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11794      US  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11795      US  US/Central         KDAL  2016-11-30 15:53:00            61.0
# A-11798      US  US/Central         KDAL  2016-11-30 15:53:00            61.0
#
#          Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# ID
# A-11786            NaN         22.0         30.01            10.0
# A-11787            NaN         22.0         30.01            10.0
# A-11794            NaN         22.0         30.01            10.0
# A-11795            NaN         22.0         30.01            10.0
# A-11798            NaN         22.0         30.01            10.0
#
#         Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# ID
# A-11786            NNW              4.6                NaN             Clear
# A-11787            NNW              4.6                NaN             Clear
# A-11794            NNW              4.6                NaN             Clear
# A-11795            NNW              4.6                NaN             Clear
# A-11798            NNW              4.6                NaN             Clear
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# ID
# A-11786    False  False     False     False      True    False    False
# A-11787    False  False     False     False     False    False    False
# A-11794    False  False     False     False      True    False    False
# A-11795    False  False      True     False     False    False    False
# A-11798    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# ID
# A-11786       False    False  False            False           False
# A-11787       False    False  False            False           False
# A-11794       False    False  False            False           False
# A-11795       False    False  False            False            True
# A-11798       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# ID
# A-11786         False            Day            Day               Day
# A-11787         False            Day            Day               Day
# A-11794         False            Day            Day               Day
# A-11795         False            Day            Day               Day
# A-11798         False            Day            Day               Day
#
#         Astronomical_Twilight
# ID
# A-11786                   Day
# A-11787                   Day
# A-11794                   Day
# A-11795                   Day
# A-11798                   Day

# %% [markdown]
# ### Confirm single-valued columns

# %%
dallas_city[['City', 'State', 'Country', 'Timezone']]
# Out:
#              City State Country    Timezone
# ID
# A-11786    Dallas    TX      US  US/Central
# A-11787    Dallas    TX      US  US/Central
# A-11794    Dallas    TX      US  US/Central
# A-11795    Dallas    TX      US  US/Central
# A-11798    Dallas    TX      US  US/Central
# ...           ...   ...     ...         ...
# A-2844612  Dallas    TX      US  US/Central
# A-2844627  Dallas    TX      US  US/Central
# A-2844632  Dallas    TX      US  US/Central
# A-2845067  Dallas    TX      US  US/Central
# A-2845068  Dallas    TX      US  US/Central
#
# [41615 rows x 4 columns]

# %% [markdown]
# ### Note:
#
# As shown in the previous jupyter notebook in basic exploration of the US-Accidents data and confirmed in the above cell, some columns share the same values all throughout this subset since we extracted Dallas City dataset. <hr>

# %% [markdown]
# ### Dropping columns

# %%
dallas_city.drop(columns=['City', 'State', 'Country', 'Timezone' ], inplace=True)
dallas_city
# Out:
#            Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-11786           2  2016-11-30 15:29:48  2016-11-30 21:29:48   32.84365
# A-11787           2  2016-11-30 15:41:16  2016-11-30 21:41:16   32.84662
# A-11794           3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.79385
# A-11795           3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.85710
# A-11798           3  2016-11-30 16:21:05  2016-11-30 22:21:05   32.87684
# ...             ...                  ...                  ...        ...
# A-2844612         3  2019-08-22 08:59:31  2019-08-22 09:27:33   32.86174
# A-2844627         3  2019-08-22 17:54:40  2019-08-22 18:23:27   32.67827
# A-2844632         3  2019-08-22 23:50:30  2019-08-23 00:19:59   32.92601
# A-2845067         3  2019-08-23 14:12:33  2019-08-23 14:41:14   32.90422
# A-2845068         2  2019-08-23 09:50:30  2019-08-23 10:18:06   32.79135
#
#            Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# ID
# A-11786   -96.774630  32.81833 -96.78806         1.915
# A-11787   -96.637360  32.84640 -96.63711         0.021
# A-11794   -96.702780  32.79498 -96.69424         0.502
# A-11795   -96.770460  32.84623 -96.77330         0.769
# A-11798   -96.810010  32.88004 -96.80963         0.222
# ...              ...       ...       ...           ...
# A-2844612 -96.657570  32.86653 -96.66512         0.549
# A-2844627 -96.822740  32.67153 -96.82262         0.466
# A-2844632 -96.820616  32.92601 -96.82072         0.006
# A-2845067 -96.769110  32.89449 -96.76926         0.672
# A-2845068 -96.813630  32.79399 -96.81444         0.188
#
#                                                  Description  Street_Number  \
# ID
# A-11786    Between Mockingbird Ln/Exit 3 and Knox St/Hend...            NaN
# A-11787                    At La Prada Dr/Exit 9 - Accident.            NaN
# A-11794                 At Jim Miller Rd/Exit 51 - Accident.            NaN
# A-11795    Between Caruth Haven Ln/Exit 4 and Lovers Ln/E...            NaN
# A-11798                        At Walnut Hill Ln - Accident.            NaN
# ...                                                      ...            ...
# A-2844612               At Northwest Hwy/Exit 11 - Accident.            NaN
# A-2844627  At Laureland Rd/Exit 420 - Accident. Two lanes...            NaN
# A-2844632                   At Dallas North Tlwy - Accident.            NaN
# A-2845067  At Royal Ln/Exit 7 - Accident. Two lanes blocked.            NaN
# A-2845068   At Hi Line Dr/Exit 429 - Accident. Lane blocked.            NaN
#
#                       Street_Name Street_Side  County Zipcode Airport_Code  \
# ID
# A-11786                   US-75 S           R  Dallas   75205         KDAL
# A-11787                   I-635 S           R  Dallas   75228         KDAL
# A-11794        R L Thornton Fwy E           R  Dallas   75228         KDAL
# A-11795         Southwestern Blvd           R  Dallas   75225         KDAL
# A-11798    Dallas North Tollway N           R  Dallas   75225         KDAL
# ...                           ...         ...     ...     ...          ...
# A-2844612                 I-635 W           R  Dallas   75228         KDAL
# A-2844627                 US-77 S           R  Dallas   75232         KRBD
# A-2844632             LBJ Express           R  Dallas   75240         KADS
# A-2845067                 US-75 S           R  Dallas   75243         KADS
# A-2845068          Stemmons Fwy N           R  Dallas   75219         KDAL
#
#              Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# ID
# A-11786    2016-11-30 15:53:00            61.0            NaN         22.0
# A-11787    2016-11-30 15:53:00            61.0            NaN         22.0
# A-11794    2016-11-30 15:53:00            61.0            NaN         22.0
# A-11795    2016-11-30 15:53:00            61.0            NaN         22.0
# A-11798    2016-11-30 15:53:00            61.0            NaN         22.0
# ...                        ...             ...            ...          ...
# A-2844612  2019-08-22 08:53:00            84.0           84.0         61.0
# A-2844627  2019-08-22 17:53:00            96.0           96.0         36.0
# A-2844632  2019-08-22 23:55:00            88.0           88.0         48.0
# A-2845067  2019-08-23 13:47:00            91.0           91.0         49.0
# A-2845068  2019-08-23 09:53:00            86.0           86.0         63.0
#
#            Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# ID
# A-11786           30.01            10.0            NNW              4.6
# A-11787           30.01            10.0            NNW              4.6
# A-11794           30.01            10.0            NNW              4.6
# A-11795           30.01            10.0            NNW              4.6
# A-11798           30.01            10.0            NNW              4.6
# ...                 ...             ...            ...              ...
# A-2844612         29.46            10.0              S              6.0
# A-2844627         29.09            10.0              S             12.0
# A-2844632         29.21            10.0            SSE              8.0
# A-2845067         29.23            10.0             NE             13.0
# A-2845068         29.42            10.0            SSE              6.0
#
#            Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# ID
# A-11786                  NaN             Clear    False  False     False
# A-11787                  NaN             Clear    False  False     False
# A-11794                  NaN             Clear    False  False     False
# A-11795                  NaN             Clear    False  False      True
# A-11798                  NaN             Clear    False  False     False
# ...                      ...               ...      ...    ...       ...
# A-2844612                0.0              Fair    False  False     False
# A-2844627                0.0              Fair    False  False     False
# A-2844632                0.0              Fair    False  False     False
# A-2845067                0.0     Mostly Cloudy    False  False     False
# A-2845068                0.0     Mostly Cloudy    False  False     False
#
#            Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# ID
# A-11786       False      True    False    False       False    False  False
# A-11787       False     False    False    False       False    False  False
# A-11794       False      True    False    False       False    False  False
# A-11795       False     False    False    False       False    False  False
# A-11798       False     False    False    False       False    False  False
# ...             ...       ...      ...      ...         ...      ...    ...
# A-2844612     False     False    False    False       False    False  False
# A-2844627     False      True    False    False       False    False  False
# A-2844632     False     False    False    False       False    False  False
# A-2845067     False     False    False    False       False    False  False
# A-2845068     False     False    False    False       False    False  False
#
#            Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# ID
# A-11786              False           False         False            Day
# A-11787              False           False         False            Day
# A-11794              False           False         False            Day
# A-11795              False            True         False            Day
# A-11798              False           False         False            Day
# ...                    ...             ...           ...            ...
# A-2844612            False           False         False            Day
# A-2844627            False           False         False            Day
# A-2844632            False           False         False          Night
# A-2845067            False           False         False            Day
# A-2845068            False           False         False            Day
#
#           Civil_Twilight Nautical_Twilight Astronomical_Twilight
# ID
# A-11786              Day               Day                   Day
# A-11787              Day               Day                   Day
# A-11794              Day               Day                   Day
# A-11795              Day               Day                   Day
# A-11798              Day               Day                   Day
# ...                  ...               ...                   ...
# A-2844612            Day               Day                   Day
# A-2844627            Day               Day                   Day
# A-2844632          Night             Night                 Night
# A-2845067            Day               Day                   Day
# A-2845068            Day               Day                   Day
#
# [41615 rows x 42 columns]

# %%
print(f'The number of columns is reduced to {dallas_city.shape[1]}.')
# Out:
# The number of columns is reduced to 46.

# %% [markdown]
# ### Checking Missing Values in Dallas City subset

# %%
na_count = dallas_city.isna().sum()
na_count[dallas_city.isna().sum()>0]
# Out:
# Number               26817
# Airport_Code             7
# Weather_Timestamp       63
# Temperature(F)          98
# Wind_Chill(F)         7964
# Humidity(%)            100
# Pressure(in)            87
# Visibility(mi)         109
# Wind_Direction         189
# Wind_Speed(mph)        810
# Precipitation(in)     7838
# Weather_Condition      123
# dtype: int64

# %%
# Replacing NAN values in the Street Number Attribute
dallas_city['Street_Number'].replace(np.nan, "Not Available", inplace=True)

# %% [markdown]
# ### Checking for duplicates

# %%
# Check if there are duplicate entries or records
dallas_city[dallas_city.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Severity, Start_Time, End_Time, Start_Lat, Start_Lng, End_Lat, End_Lng, Distance(mi), Description, Street_Number, Street_Name, Street_Side, County, Zipcode, Airport_Code, Weather_Timestamp, Temperature(F), Wind_Chill(F), Humidity(%), Pressure(in), Visibility(mi), Wind_Direction, Wind_Speed(mph), Precipitation(in), Weather_Condition, Amenity, Bump, Crossing, Give_Way, Junction, No_Exit, Railway, Roundabout, Station, Stop, Traffic_Calming, Traffic_Signal, Turning_Loop, Sunrise_Sunset, Civil_Twilight, Nautical_Twilight, Astronomical_Twilight]
# Index: []

# %% [markdown]
# ### Note: There are no duplicates in the data <hr>

# %%
dallas_city.loc['A-2845067', 'Description']
# Out:
# 'At Royal Ln/Exit 7 - Accident. Two lanes blocked.'

# %% [markdown]
# ## Display records with NaN values in attribute "Weather Condition" <hr>

# %%
dallas_city[dallas_city['Weather_Condition'].isna()].head()
# Out:
#           Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-215795         2  2017-07-23 23:32:16  2017-07-24 05:32:16  32.713205
# A-215805         2  2017-07-24 05:32:16  2017-07-24 11:32:16  32.703750
# A-299688         2  2021-04-08 08:07:40  2021-04-08 09:26:59  32.795959
# A-441817         2  2021-03-20 04:39:28  2021-03-20 06:57:29  32.807651
# A-618152         2  2021-04-08 07:45:00  2021-04-08 09:02:59  32.742866
#
#           Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# ID
# A-215795 -96.683363  32.711090 -96.680310         0.230
# A-215805 -96.663020  32.709250 -96.677130         0.904
# A-299688 -96.745138  32.795730 -96.745369         0.021
# A-441817 -96.757239  32.809514 -96.759432         0.181
# A-618152 -96.753416  32.742679 -96.753415         0.013
#
#                                                 Description  Street_Number  \
# ID
# A-215795                          At TX-12-loop - Accident.  Not Available
# A-215805                    At Prairie Creek Rd - Accident.  Not Available
# A-299688  Incident on EAST GRAND AVE near GRANDVIEW AVE ...         5901.0
# A-441817  Incident on SKILLMAN ST near JUNIUS ST Drive w...         5848.0
# A-618152  Incident on BEXAR ST near BUDD ST Drive with c...         5906.0
#
#              Street_Name Street_Side  County     Zipcode Airport_Code  \
# ID
# A-215795  S Buckner Blvd           R  Dallas       75217         KHQZ
# A-215805      Hawn Fwy W           R  Dallas       75217         KHQZ
# A-299688     E Grand Ave           L  Dallas  75223-1539         KDAL
# A-441817       Junius St           R  Dallas       75214         KDAL
# A-618152        Bexar St           L  Dallas       75215         KDAL
#
#             Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# ID
# A-215795  2017-07-23 23:35:00             NaN            NaN          NaN
# A-215805  2017-07-24 05:35:00             NaN            NaN          NaN
# A-299688  2021-04-08 07:53:00            54.0           54.0         75.0
# A-441817  2021-03-20 04:53:00            45.0           45.0         74.0
# A-618152  2021-04-08 07:53:00            54.0           54.0         75.0
#
#           Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# ID
# A-215795           NaN             NaN          North              NaN
# A-215805           NaN             NaN          North              NaN
# A-299688         29.36            10.0            NNW              6.0
# A-441817         29.78            10.0           CALM              0.0
# A-618152         29.36            10.0            NNW              6.0
#
#           Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# ID
# A-215795                NaN               NaN    False  False     False
# A-215805                NaN               NaN    False  False     False
# A-299688                0.0               NaN    False  False     False
# A-441817                0.0               NaN    False  False     False
# A-618152                0.0               NaN    False  False     False
#
#           Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# ID
# A-215795     False     False    False    False       False    False  False
# A-215805     False     False    False    False       False    False  False
# A-299688     False     False    False    False       False    False  False
# A-441817     False     False    False    False       False    False  False
# A-618152     False     False    False    False       False    False  False
#
#           Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# ID
# A-215795            False           False         False          Night
# A-215805            False           False         False          Night
# A-299688            False           False         False            Day
# A-441817            False           False         False          Night
# A-618152            False           False         False            Day
#
#          Civil_Twilight Nautical_Twilight Astronomical_Twilight
# ID
# A-215795          Night             Night                 Night
# A-215805          Night             Night                   Day
# A-299688            Day               Day                   Day
# A-441817          Night             Night                 Night
# A-618152            Day               Day                   Day

# %%
dallas_city.Weather_Condition.value_counts()
# Out:
# Fair                            14965
# Mostly Cloudy                    7017
# Cloudy                           5482
# Partly Cloudy                    4626
# Clear                            2371
# Overcast                         1601
# Light Rain                       1595
# Scattered Clouds                  926
# Rain                              449
# Fog                               365
# Fair / Windy                      297
# Light Drizzle                     260
# Haze                              226
# Heavy Rain                        149
# T-Storm                           149
# Light Rain with Thunder           126
# Mostly Cloudy / Windy              97
# Cloudy / Windy                     80
# Thunder                            78
# Heavy T-Storm                      73
# Light Thunderstorms and Rain       60
# Partly Cloudy / Windy              59
# Light Snow                         55
# Drizzle                            50
# Blowing Dust                       50
# Thunderstorms and Rain             48
# Thunderstorm                       38
# Thunder in the Vicinity            36
# Wintry Mix                         36
# Heavy Thunderstorms and Rain       26
# Light Freezing Drizzle             17
# Showers in the Vicinity            13
# Heavy T-Storm / Windy              13
# Snow                               11
# Light Rain / Windy                  8
# Thunder / Windy                     6
# T-Storm / Windy                     5
# Heavy Rain / Windy                  4
# N/A Precipitation                   3
# Mist                                2
# Snow Grains                         2
# Light Freezing Rain                 2
# Light Snow and Sleet                2
# Light Drizzle / Windy               2
# Patches of Fog                      2
# Fog / Windy                         1
# Rain Showers                        1
# Light Rain Showers                  1
# Heavy Rain Showers                  1
# Light Fog                           1
# Blowing Dust / Windy                1
# Widespread Dust                     1
# Freezing Rain                       1
# Light Snow / Windy                  1
# Rain / Windy                        1
# Name: Weather_Condition, dtype: int64

# %%
#Exploring accidents with Weather Conditions 
dallas_city[dallas_city['Weather_Condition'].isna()!=True].head()
# Out:
#          Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-11786         2  2016-11-30 15:29:48  2016-11-30 21:29:48   32.84365
# A-11787         2  2016-11-30 15:41:16  2016-11-30 21:41:16   32.84662
# A-11794         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.79385
# A-11795         3  2016-11-30 16:16:05  2016-11-30 22:16:05   32.85710
# A-11798         3  2016-11-30 16:21:05  2016-11-30 22:21:05   32.87684
#
#          Start_Lng   End_Lat   End_Lng  Distance(mi)  \
# ID
# A-11786  -96.77463  32.81833 -96.78806         1.915
# A-11787  -96.63736  32.84640 -96.63711         0.021
# A-11794  -96.70278  32.79498 -96.69424         0.502
# A-11795  -96.77046  32.84623 -96.77330         0.769
# A-11798  -96.81001  32.88004 -96.80963         0.222
#
#                                                Description  Street_Number  \
# ID
# A-11786  Between Mockingbird Ln/Exit 3 and Knox St/Hend...  Not Available
# A-11787                  At La Prada Dr/Exit 9 - Accident.  Not Available
# A-11794               At Jim Miller Rd/Exit 51 - Accident.  Not Available
# A-11795  Between Caruth Haven Ln/Exit 4 and Lovers Ln/E...  Not Available
# A-11798                      At Walnut Hill Ln - Accident.  Not Available
#
#                     Street_Name Street_Side  County Zipcode Airport_Code  \
# ID
# A-11786                 US-75 S           R  Dallas   75205         KDAL
# A-11787                 I-635 S           R  Dallas   75228         KDAL
# A-11794      R L Thornton Fwy E           R  Dallas   75228         KDAL
# A-11795       Southwestern Blvd           R  Dallas   75225         KDAL
# A-11798  Dallas North Tollway N           R  Dallas   75225         KDAL
#
#            Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# ID
# A-11786  2016-11-30 15:53:00            61.0            NaN         22.0
# A-11787  2016-11-30 15:53:00            61.0            NaN         22.0
# A-11794  2016-11-30 15:53:00            61.0            NaN         22.0
# A-11795  2016-11-30 15:53:00            61.0            NaN         22.0
# A-11798  2016-11-30 15:53:00            61.0            NaN         22.0
#
#          Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# ID
# A-11786         30.01            10.0            NNW              4.6
# A-11787         30.01            10.0            NNW              4.6
# A-11794         30.01            10.0            NNW              4.6
# A-11795         30.01            10.0            NNW              4.6
# A-11798         30.01            10.0            NNW              4.6
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# ID
# A-11786                NaN             Clear    False  False     False
# A-11787                NaN             Clear    False  False     False
# A-11794                NaN             Clear    False  False     False
# A-11795                NaN             Clear    False  False      True
# A-11798                NaN             Clear    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# ID
# A-11786     False      True    False    False       False    False  False
# A-11787     False     False    False    False       False    False  False
# A-11794     False      True    False    False       False    False  False
# A-11795     False     False    False    False       False    False  False
# A-11798     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# ID
# A-11786            False           False         False            Day
# A-11787            False           False         False            Day
# A-11794            False           False         False            Day
# A-11795            False            True         False            Day
# A-11798            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight
# ID
# A-11786            Day               Day                   Day
# A-11787            Day               Day                   Day
# A-11794            Day               Day                   Day
# A-11795            Day               Day                   Day
# A-11798            Day               Day                   Day

# %%
# Exploring accidents where the Weather Condition is Mostly Cloudy
dallas_city[dallas_city['Weather_Condition']=='Mostly Cloudy'].head()
# Out:
#          Severity           Start_Time             End_Time  Start_Lat  \
# ID
# A-11958         2  2016-12-02 06:09:42  2016-12-02 12:09:42  32.710834
# A-11959         2  2016-12-02 06:12:20  2016-12-02 12:12:20  32.720320
# A-11974         3  2016-12-02 08:16:26  2016-12-02 14:16:26  32.770532
# A-12001         2  2016-12-02 11:28:37  2016-12-02 17:28:37  32.797700
# A-12005         2  2016-12-02 11:44:46  2016-12-02 17:44:46  32.656847
#
#          Start_Lng   End_Lat    End_Lng  Distance(mi)  \
# ID
# A-11958 -96.800029  32.71083 -96.800032         0.000
# A-11959 -96.830360  32.72036 -96.827866         0.145
# A-11974 -96.814267  32.77061 -96.811786         0.144
# A-12001 -96.684500  32.79579 -96.692020         0.456
# A-12005 -96.750508  32.65453 -96.750640         0.160
#
#                                                Description  Street_Number  \
# ID
# A-11958                           At Biglow Dr - Accident.         3100.0
# A-11959  Between TX-354-LOOP/S Zang Blvd and I-35E/US-6...          444.0
# A-11974                       At I-30/Exit 428 - Accident.  Not Available
# A-12001              At St Francis Ave/Exit 52 - Accident.  Not Available
# A-12005           At I-20/Lyndon B Johnson Fwy - Accident.         7380.0
#
#                 Street_Name Street_Side  County     Zipcode Airport_Code  \
# ID
# A-11958           Biglow Dr           L  Dallas       75216         KRBD
# A-11959      W Illinois Ave           L  Dallas  75224-2204         KRBD
# A-11974      Tom Landry Fwy           R  Dallas       75207         KDAL
# A-12001  R L Thornton Fwy E           R  Dallas       75228         KDAL
# A-12005      Bonnie View Rd           L  Dallas  75241-7005         KRBD
#
#            Weather_Timestamp  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# ID
# A-11958  2016-12-02 05:53:00            45.0           42.6         71.0
# A-11959  2016-12-02 05:53:00            45.0           42.6         71.0
# A-11974  2016-12-02 07:53:00            46.9            NaN         68.0
# A-12001  2016-12-02 11:22:00            59.0            NaN         44.0
# A-12005  2016-12-02 11:53:00            57.9            NaN         53.0
#
#          Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# ID
# A-11958         30.09            10.0            ESE              4.6
# A-11959         30.09            10.0            ESE              4.6
# A-11974         30.15            10.0            ENE              3.5
# A-12001         30.16            10.0            ESE              9.2
# A-12005         30.12            10.0            ESE              6.9
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# ID
# A-11958                NaN     Mostly Cloudy    False  False     False
# A-11959                NaN     Mostly Cloudy    False  False     False
# A-11974                NaN     Mostly Cloudy    False  False     False
# A-12001                NaN     Mostly Cloudy    False  False     False
# A-12005                NaN     Mostly Cloudy    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# ID
# A-11958     False     False    False    False       False    False  False
# A-11959     False     False    False    False       False    False  False
# A-11974     False      True    False    False       False    False  False
# A-12001     False      True    False    False       False    False  False
# A-12005     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# ID
# A-11958            False           False         False          Night
# A-11959            False            True         False          Night
# A-11974            False           False         False            Day
# A-12001            False           False         False            Day
# A-12005            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight
# ID
# A-11958          Night             Night                   Day
# A-11959          Night             Night                   Day
# A-11974            Day               Day                   Day
# A-12001            Day               Day                   Day
# A-12005            Day               Day                   Day

# %%
# Checking the number of accidents that fall under each Severity Levels under Mostly Cloudly weather condition

dallas_city[dallas_city['Weather_Condition']=='Mostly Cloudy']['Severity'].value_counts()
# Out:
# 2    6009
# 3     883
# 4     125
# Name: Severity, dtype: int64

# %% [markdown]
# ## Using Advanced Matplotlib API <hr>

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,10))
ax[0][0].hist(dallas_city.Severity, edgecolor='black', bins=10)
ax[0][0].set_xlabel('Accident Severity')
ax[0][0].set_ylabel('Frequency of Accidents')
ax[0][0].set_title('Frequency vs Severity')
# ax[0][1].scatter(dallas_city.ID,dallas_city.Severity)
# ax[0][1].set_xlabel('Accident Severity')
# ax[0][1].set_ylabel('Frequency of Accidents')
# ax[0][1].set_title('Frequency vs Severity')
plt.show()

# %%
dallas_city.hist(bins=30, figsize=(20,15), color='green', edgecolor='black')
plt.show()

# %%
plt.hist(dallas_city.Severity, bins=[1,2,3,4,5], edgecolor='black', rwidth=0.8, color='blue')
plt.title("Frequency vs Severity")
plt.xlabel("Severity")
plt.ylabel("Frequency of Accidents")
plt.show()

# %%
dallas_city[['Severity','Description']]
# Out:
#            Severity                                        Description
# ID
# A-11786           2  Between Mockingbird Ln/Exit 3 and Knox St/Hend...
# A-11787           2                  At La Prada Dr/Exit 9 - Accident.
# A-11794           3               At Jim Miller Rd/Exit 51 - Accident.
# A-11795           3  Between Caruth Haven Ln/Exit 4 and Lovers Ln/E...
# A-11798           3                      At Walnut Hill Ln - Accident.
# ...             ...                                                ...
# A-2844612         3               At Northwest Hwy/Exit 11 - Accident.
# A-2844627         3  At Laureland Rd/Exit 420 - Accident. Two lanes...
# A-2844632         3                   At Dallas North Tlwy - Accident.
# A-2845067         3  At Royal Ln/Exit 7 - Accident. Two lanes blocked.
# A-2845068         2   At Hi Line Dr/Exit 429 - Accident. Lane blocked.
#
# [41615 rows x 2 columns]
